# %% [markdown]
# ## Initial Prediction Model
# The original README file says:
# > Often, more than one contact to the same client was required, **in order to access if the product (bank term deposit) would be (or not) subscribed**
#
# Therefore, let's start with a simple binary classification model to predict Deposit yes/no

# %%
#import the right libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, log_loss, roc_auc_score, hamming_loss, fbeta_score, auc, roc_curve, precision_score, recall_score
from sklearn.model_selection import cross_val_predict, cross_val_score, learning_curve, GridSearchCV, RandomizedSearchCV, StratifiedShuffleSplit, train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, Normalizer, LabelEncoder, RobustScaler, MinMaxScaler
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# %%
#this option just allwos us to see every column in the notebook
pd.set_option('display.max_columns', None)

#pd.get_option("display.max_columns")

# %%
#pull in the dataset and turn into a DataFrame
bank_main_df = pd.read_csv('./Dataset_1_Bank Marketing/bank_marketing.csv',delimiter=';')
bank_main_df
# Out:
#         age           job   marital  education default  balance housing loan  \
# 0      58.0    management   married   tertiary      no     2143     yes   no
# 1      44.0    technician    single  secondary      no       29     yes   no
# 2      33.0  entrepreneur   married  secondary      no        2     yes  yes
# 3      47.0   blue-collar   married    unknown      no     1506     yes   no
# 4      33.0       unknown    single    unknown      no        1      no   no
# ...     ...           ...       ...        ...     ...      ...     ...  ...
# 45206  51.0    technician   married   tertiary      no      825      no   no
# 45207  71.0       retired  divorced    primary      no     1729      no   no
# 45208  72.0       retired   married  secondary      no     5715      no   no
# 45209  57.0   blue-collar   married  secondary      no      668      no   no
# 45210  37.0  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0        unknown    5   may       261         1     -1         0  unknown
# 1        unknown    5   may       151         1     -1         0  unknown
# 2        unknown    5   may        76         1     -1         0  unknown
# 3        unknown    5   may        92         1     -1         0  unknown
# 4            NaN    5   may       198         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other
#
#       deposit
# 0          no
# 1          no
# 2          no
# 3          no
# 4          no
# ...       ...
# 45206     yes
# 45207     yes
# 45208     yes
# 45209      no
# 45210      no
#
# [45211 rows x 17 columns]

# %%
bank_main_df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  43872.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.924781    1362.272058     15.806419    258.163080      2.763841
# std       10.610835    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
#creating a field that determines whether or not the customer was ever previously contacted
bank_main_df['prior_contact'] = [ 0 if bank_main_df['pdays'][i] == -1 else 1 for i in range(len(bank_main_df))]

#replacing the yes/no categorical values with 1/0 binary digits
bank_main_df['deposit'] = [1 if (bank_main_df['deposit'][i] == 'yes') else 0 for i in range(len(bank_main_df)) ]

#convert the "day" field to a categorical variable
bank_main_df['day'] = pd.Categorical(bank_main_df['day'])

#dropping pdays and previous, because the important information is captured in prior_contact
bank_main_df.drop(columns=['pdays','previous'],inplace=True)

# %%
#because we have so many cateogrical variables, we should one-hot encode them (i.e. create dummy categorical variables)
#we also use drop_first=True to reduce the redundant column count 
bank_main_df = pd.get_dummies(bank_main_df, drop_first=False)

# bank_main_df

# %%
#note that only the "age" category has null values

# pd.isnull(bank_main_df).sum()

# %% [markdown]
# # Imputing the missing values in "Age" variable
#
# * **Iterative Imputer:**
# Multivariate imputer that estimates each feature from all the others. A strategy for imputing missing values by modeling each feature with missing values as a function of other features in a round-robin fashion.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html

# %%
# Use multivariate imputer that estimates and imputes null values based on all the others. 

imp = IterativeImputer(max_iter=10, verbose=0) # values passed are defaults, but added them because they seem important... play around
imp.fit(bank_main_df)
imputed_df = imp.transform(bank_main_df)
imputed_df = pd.DataFrame(imputed_df, columns=bank_main_df.columns)

# %%
# pd.isnull(imputed_df).sum()

# %% [markdown]
# # R-Forest Feature Importance

# %%
#scaler = StandardScaler() 
#X_scaled = scaler.fit_transform(imputed_df)

#X = imputed_df.drop(columns='deposit')
#y = imputed_df['deposit']

#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, shuffle=True, random_state=42)

# %% [markdown]
# # Loop through all classifiers

# %% [markdown]
# ### MinMaxScaler

# %%
# StandardScaler, MinMaxScaler, RobustScaler
#scaler = RobustScaler() 
#X_scaled = scaler.fit_transform(imputed_df)

X = imputed_df.drop(columns='deposit')
y = imputed_df['deposit']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, shuffle=True)

scaler = MinMaxScaler() 
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
classifiers = [
#     MultinomialNB(), # doesn't work
    KNeighborsClassifier(3), # works
#     SVC(kernel="rbf", C=0.001, probability=True), # took a long time... need to refresh memory
#     SVC(kernel='linear'), # took a long time... need to refresh memory
#     NuSVC(probability=True, nu=0.1), # took a long time... need to refresh memory
    DecisionTreeClassifier(), # works
    RandomForestClassifier(), # works
    AdaBoostClassifier(), # works
    GradientBoostingClassifier(), # works
    GaussianNB(), # works
    BernoulliNB(), # works
    MLPClassifier(), # works
    MLPClassifier(hidden_layer_sizes=[100, 100]), # works
    LinearDiscriminantAnalysis(), # works
    LogisticRegression(), # works
    QuadraticDiscriminantAnalysis(), # works
]

log_cols=["Classifier", "Accuracy", "F1 Score", "ROC", "Precision", "Recall", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, y_train)
#     y_pred = clf.predict(X)
    name = clf.__class__.__name__

    print("="*60)
    print(name)
    print('****Results****')

    train_predictions = clf.predict(X_test)
    acc_ = accuracy_score(y_test, train_predictions)
    acc = acc_.round(3)
    print("Accuracy: {:.4%}".format(acc))

#     coef_scores = X_scaled
#     coef_scores = clf.coef_
#     print(coef_scores)

    fbeta_ = fbeta_score(y_test, train_predictions, beta=1)
    fbeta = fbeta_.round(3)
    print("F1 Score: {}".format(fbeta))

    roc_ = roc_auc_score(y_test, train_predictions)
    roc = roc_.round(3)
    print("AUC (ROC) Score: {}".format(roc))

    precision_ = precision_score(y_test, train_predictions, average='binary')
    precision = precision_.round(3)
    print("Precision Score: {}".format(precision))

    recall_ = recall_score(y_test, train_predictions)
    recall = recall_.round(3)
    print("Recall Score: {}".format(recall))
    
    print(f"\nClassic train score: {np.round(clf.score(X_train, y_train),4)}")
    print(f"Classic test score: {np.round(clf.score(X_test, y_test),4)}")
    confusion_matrix_ = confusion_matrix(y_test, train_predictions)
    print(f"Confusion matrix: \n{confusion_matrix_}\n")

#     train_predictions = clf.predict_proba(X_test)
    ll_ = log_loss(y_test, train_predictions)
    ll = ll_.round(3)
#     print("Log Loss: {}".format(ll))

    log_entry = pd.DataFrame([[name, acc*100, fbeta, roc, precision, recall, ll]], columns=log_cols)
    log = pd.concat([log,log_entry])

# print("="*30)
# type(coef_scores)
# print(index)
# print(log_entry)
# type(log)
# Out:
# ============================================================
# KNeighborsClassifier
# ****Results****
# Accuracy: 88.3000%
# F1 Score: 0.32
# AUC (ROC) Score: 0.602
# Precision Score: 0.506
# Recall Score: 0.234
#
# Classic train score: 0.9278
# Classic test score: 0.8831
# Confusion matrix:
# [[11605   364]
#  [ 1222   373]]
#
# ============================================================
# DecisionTreeClassifier
# ****Results****
# Accuracy: 87.3000%
# F1 Score: 0.465
# AUC (ROC) Score: 0.698
# Precision Score: 0.462
# Recall Score: 0.469
#
# Classic train score: 1.0
# Classic test score: 0.8733
# Confusion matrix:
# [[11098   871]
#  [  847   748]]
#
# ============================================================
# RandomForestClassifier
# ****Results****
# Accuracy: 90.1000%
# F1 Score: 0.441
# AUC (ROC) Score: 0.655
# Precision Score: 0.653
# Recall Score: 0.333
#
# Classic train score: 1.0
# Classic test score: 0.9008
# Confusion matrix:
# [[11687   282]
#  [ 1064   531]]
#
# ============================================================
# AdaBoostClassifier
# ****Results****
# Accuracy: 89.9000%
# F1 Score: 0.468
# AUC (ROC) Score: 0.674
# Precision Score: 0.611
# Recall Score: 0.38
#
# Classic train score: 0.9015
# Classic test score: 0.8986
# Confusion matrix:
# [[11583   386]
#  [  989   606]]
#
# ============================================================
# GradientBoostingClassifier
# ****Results****
# Accuracy: 90.3000%
# F1 Score: 0.487
# AUC (ROC) Score: 0.682
# Precision Score: 0.641
# Recall Score: 0.392
#
# Classic train score: 0.9111
# Classic test score: 0.9028
# Confusion matrix:
# [[11619   350]
#  [  969   626]]
#
# ============================================================
# GaussianNB
# ****Results****
# Accuracy: 83.1000%
# F1 Score: 0.426
# AUC (ROC) Score: 0.702
# Precision Score: 0.355
# Recall Score: 0.533
#
# Classic train score: 0.835
# Classic test score: 0.8312
# Confusion matrix:
# [[10424  1545]
#  [  745   850]]
#
# ============================================================
# BernoulliNB
# ****Results****
# Accuracy: 85.4000%
# F1 Score: 0.385
# AUC (ROC) Score: 0.653
# Precision Score: 0.381
# Recall Score: 0.389
#
# Classic train score: 0.8569
# Classic test score: 0.854
# Confusion matrix:
# [[10962  1007]
#  [  974   621]]
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ============================================================
# MLPClassifier
# ****Results****
# Accuracy: 89.3000%
# F1 Score: 0.538
# AUC (ROC) Score: 0.736
# Precision Score: 0.547
# Recall Score: 0.53
#
# Classic train score: 0.9682
# Classic test score: 0.8931
# Confusion matrix:
# [[11269   700]
#  [  750   845]]
#
# ============================================================
# MLPClassifier
# ****Results****
# Accuracy: 87.4000%
# F1 Score: 0.509
# AUC (ROC) Score: 0.735
# Precision Score: 0.471
# Recall Score: 0.553
#
# Classic train score: 0.9854
# Classic test score: 0.8744
# Confusion matrix:
# [[10979   990]
#  [  713   882]]
#
# ============================================================
# LinearDiscriminantAnalysis
# ****Results****
# Accuracy: 90.2000%
# F1 Score: 0.515
# AUC (ROC) Score: 0.703
# Precision Score: 0.618
# Recall Score: 0.441
#
# Classic train score: 0.9012
# Classic test score: 0.9022
# Confusion matrix:
# [[11534   435]
#  [  891   704]]
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# ============================================================
# LogisticRegression
# ****Results****
# Accuracy: 90.0000%
# F1 Score: 0.437
# AUC (ROC) Score: 0.653
# Precision Score: 0.651
# Recall Score: 0.329
#
# Classic train score: 0.9028
# Classic test score: 0.9003
# Confusion matrix:
# [[11687   282]
#  [ 1070   525]]
#
# ============================================================
# QuadraticDiscriminantAnalysis
# ****Results****
# Accuracy: 80.0000%
# F1 Score: 0.428
# AUC (ROC) Score: 0.728
# Precision Score: 0.323
# Recall Score: 0.634
#
# Classic train score: 0.8018
# Classic test score: 0.8004
# Confusion matrix:
# [[9846 2123]
#  [ 584 1011]]

# %%
# Save DF as PNG
def render_mpl_table(imputed_df, col_width=6.0, row_height=0.625, font_size=10,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(imputed_df.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')
    mpl_table = ax.table(cellText=imputed_df.values, bbox=bbox, colLabels=imputed_df.columns, **kwargs)
    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in mpl_table._cells.items():
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax.get_figure(), ax

fig,ax = render_mpl_table(log, header_columns=0, col_width=3.0)
fig.savefig("table_mpl.png")

# %%
log1 = log.set_index('Classifier')

norm_df = log1 / log1.max(0)

sns.heatmap(norm_df.astype('float'),cmap='coolwarm')
# Out:
# <AxesSubplot:ylabel='Classifier'>

# %% [markdown]
# ### StandardScaler

# %%
# StandardScaler, MinMaxScaler, RobustScaler
#scaler = RobustScaler() 
#X_scaled = scaler.fit_transform(imputed_df)

X = imputed_df.drop(columns='deposit')
y = imputed_df['deposit']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, shuffle=True)

scaler = StandardScaler() 
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
classifiers = [
#     MultinomialNB(), # doesn't work
    KNeighborsClassifier(3), # works
#     SVC(kernel="rbf", C=0.001, probability=True), # took a long time... need to refresh memory
#     SVC(kernel='linear'), # took a long time... need to refresh memory
#     NuSVC(probability=True, nu=0.1), # took a long time... need to refresh memory
    DecisionTreeClassifier(), # works
    RandomForestClassifier(), # works
    AdaBoostClassifier(), # works
    GradientBoostingClassifier(), # works
    GaussianNB(), # works
    BernoulliNB(), # works
    MLPClassifier(), # works
    MLPClassifier(hidden_layer_sizes=[100, 100]), # works
    LinearDiscriminantAnalysis(), # works
    LogisticRegression(), # works
    QuadraticDiscriminantAnalysis(), # works
]

log_cols=["Classifier", "Accuracy", "F1 Score", "ROC", "Precision", "Recall", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, y_train)
#     y_pred = clf.predict(X)
    name = clf.__class__.__name__

    print("="*60)
    print(name)
    print('****Results****')

    train_predictions = clf.predict(X_test)
    acc_ = accuracy_score(y_test, train_predictions)
    acc = acc_.round(3)
    print("Accuracy: {:.4%}".format(acc))

#     coef_scores = X_scaled
#     coef_scores = clf.coef_
#     print(coef_scores)

    fbeta_ = fbeta_score(y_test, train_predictions, beta=1)
    fbeta = fbeta_.round(3)
    print("F1 Score: {}".format(fbeta))

    roc_ = roc_auc_score(y_test, train_predictions)
    roc = roc_.round(3)
    print("AUC (ROC) Score: {}".format(roc))

    precision_ = precision_score(y_test, train_predictions, average='binary')
    precision = precision_.round(3)
    print("Precision Score: {}".format(precision))

    recall_ = recall_score(y_test, train_predictions)
    recall = recall_.round(3)
    print("Recall Score: {}".format(recall))
    
    print(f"\nClassic train score: {np.round(clf.score(X_train, y_train),4)}")
    print(f"Classic test score: {np.round(clf.score(X_test, y_test),4)}")
    confusion_matrix_ = confusion_matrix(y_test, train_predictions)
    print(f"Confusion matrix: \n{confusion_matrix_}\n")

#     train_predictions = clf.predict_proba(X_test)
    ll_ = log_loss(y_test, train_predictions)
    ll = ll_.round(3)
#     print("Log Loss: {}".format(ll))

    log_entry = pd.DataFrame([[name, acc*100, fbeta, roc, precision, recall, ll]], columns=log_cols)
    log = pd.concat([log,log_entry])

# print("="*30)
# type(coef_scores)
# print(index)
# print(log_entry)
# type(log)
# Out:
# ============================================================
# KNeighborsClassifier
# ****Results****
# Accuracy: 88.7000%
# F1 Score: 0.368
# AUC (ROC) Score: 0.625
# Precision Score: 0.524
# Recall Score: 0.283
#
# Classic train score: 0.9274
# Classic test score: 0.8871
# Confusion matrix:
# [[11588   404]
#  [ 1127   445]]
#
# ============================================================
# DecisionTreeClassifier
# ****Results****
# Accuracy: 87.7000%
# F1 Score: 0.474
# AUC (ROC) Score: 0.703
# Precision Score: 0.471
# Recall Score: 0.477
#
# Classic train score: 1.0
# Classic test score: 0.8772
# Confusion matrix:
# [[11148   844]
#  [  822   750]]
#
# ============================================================
# RandomForestClassifier
# ****Results****
# Accuracy: 90.6000%
# F1 Score: 0.48
# AUC (ROC) Score: 0.675
# Precision Score: 0.667
# Recall Score: 0.375
#
# Classic train score: 1.0
# Classic test score: 0.9059
# Confusion matrix:
# [[11697   295]
#  [  982   590]]
#
# ============================================================
# AdaBoostClassifier
# ****Results****
# Accuracy: 89.9000%
# F1 Score: 0.456
# AUC (ROC) Score: 0.667
# Precision Score: 0.605
# Recall Score: 0.366
#
# Classic train score: 0.9004
# Classic test score: 0.8988
# Confusion matrix:
# [[11616   376]
#  [  997   575]]
#
# ============================================================
# GradientBoostingClassifier
# ****Results****
# Accuracy: 90.6000%
# F1 Score: 0.504
# AUC (ROC) Score: 0.692
# Precision Score: 0.65
# Recall Score: 0.412
#
# Classic train score: 0.9103
# Classic test score: 0.9061
# Confusion matrix:
# [[11643   349]
#  [  924   648]]
#
# ============================================================
# GaussianNB
# ****Results****
# Accuracy: 82.8000%
# F1 Score: 0.414
# AUC (ROC) Score: 0.696
# Precision Score: 0.342
# Recall Score: 0.523
#
# Classic train score: 0.8352
# Classic test score: 0.8283
# Confusion matrix:
# [[10413  1579]
#  [  750   822]]
#
# ============================================================
# BernoulliNB
# ****Results****
# Accuracy: 86.3000%
# F1 Score: 0.432
# AUC (ROC) Score: 0.684
# Precision Score: 0.415
# Recall Score: 0.45
#
# Classic train score: 0.8669
# Classic test score: 0.8627
# Confusion matrix:
# [[10993   999]
#  [  864   708]]
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ============================================================
# MLPClassifier
# ****Results****
# Accuracy: 88.6000%
# F1 Score: 0.495
# AUC (ROC) Score: 0.71
# Precision Score: 0.508
# Recall Score: 0.482
#
# Classic train score: 0.9869
# Classic test score: 0.8858
# Confusion matrix:
# [[11257   735]
#  [  814   758]]
#
# ============================================================
# MLPClassifier
# ****Results****
# Accuracy: 89.2000%
# F1 Score: 0.516
# AUC (ROC) Score: 0.72
# Precision Score: 0.536
# Recall Score: 0.496
#
# Classic train score: 0.9975
# Classic test score: 0.8919
# Confusion matrix:
# [[11318   674]
#  [  792   780]]
#
# ============================================================
# LinearDiscriminantAnalysis
# ****Results****
# Accuracy: 90.1000%
# F1 Score: 0.509
# AUC (ROC) Score: 0.702
# Precision Score: 0.595
# Recall Score: 0.445
#
# Classic train score: 0.9012
# Classic test score: 0.9005
# Confusion matrix:
# [[11516   476]
#  [  873   699]]
#
# ============================================================
# LogisticRegression
# ****Results****
# Accuracy: 90.2000%
# F1 Score: 0.455
# AUC (ROC) Score: 0.663
# Precision Score: 0.645
# Recall Score: 0.352
#
# Classic train score: 0.9026
# Classic test score: 0.9024
# Confusion matrix:
# [[11687   305]
#  [ 1019   553]]
#
# ============================================================
# QuadraticDiscriminantAnalysis
# ****Results****
# Accuracy: 85.5000%
# F1 Score: 0.338
# AUC (ROC) Score: 0.623
# Precision Score: 0.359
# Recall Score: 0.32
#
# Classic train score: 0.8593
# Classic test score: 0.8551
# Confusion matrix:
# [[11095   897]
#  [ 1069   503]]
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# Save DF as PNG
def render_mpl_table(imputed_df, col_width=6.0, row_height=0.625, font_size=10,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(imputed_df.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')
    mpl_table = ax.table(cellText=imputed_df.values, bbox=bbox, colLabels=imputed_df.columns, **kwargs)
    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in mpl_table._cells.items():
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax.get_figure(), ax

fig,ax = render_mpl_table(log, header_columns=0, col_width=3.0)
fig.savefig("table_mpl.png")

# %%
log1 = log.set_index('Classifier')

norm_df = log1 / log1.max(0)

sns.heatmap(norm_df.astype('float'),cmap='coolwarm')
# Out:
# <AxesSubplot:ylabel='Classifier'>

# %% [markdown]
# ### RobustScaler

# %%
# StandardScaler, MinMaxScaler, RobustScaler
#scaler = RobustScaler() 
#X_scaled = scaler.fit_transform(imputed_df)

X = imputed_df.drop(columns='deposit')
y = imputed_df['deposit']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, shuffle=True)

scaler = RobustScaler() 
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
classifiers = [
#     MultinomialNB(), # doesn't work
    KNeighborsClassifier(3), # works
#     SVC(kernel="rbf", C=0.001, probability=True), # took a long time... need to refresh memory
#     SVC(kernel='linear'), # took a long time... need to refresh memory
#     NuSVC(probability=True, nu=0.1), # took a long time... need to refresh memory
    DecisionTreeClassifier(), # works
    RandomForestClassifier(), # works
    AdaBoostClassifier(), # works
    GradientBoostingClassifier(), # works
    GaussianNB(), # works
    BernoulliNB(), # works
    MLPClassifier(), # works
    MLPClassifier(hidden_layer_sizes=[100, 100]), # works
    LinearDiscriminantAnalysis(), # works
    LogisticRegression(), # works
    QuadraticDiscriminantAnalysis(), # works
]

log_cols=["Classifier", "Accuracy", "F1 Score", "ROC", "Precision", "Recall", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, y_train)
#     y_pred = clf.predict(X)
    name = clf.__class__.__name__

    print("="*60)
    print(name)
    print('****Results****')

    train_predictions = clf.predict(X_test)
    acc_ = accuracy_score(y_test, train_predictions)
    acc = acc_.round(3)
    print("Accuracy: {:.4%}".format(acc))

#     coef_scores = X_scaled
#     coef_scores = clf.coef_
#     print(coef_scores)

    fbeta_ = fbeta_score(y_test, train_predictions, beta=1)
    fbeta = fbeta_.round(3)
    print("F1 Score: {}".format(fbeta))

    roc_ = roc_auc_score(y_test, train_predictions)
    roc = roc_.round(3)
    print("AUC (ROC) Score: {}".format(roc))

    precision_ = precision_score(y_test, train_predictions, average='binary')
    precision = precision_.round(3)
    print("Precision Score: {}".format(precision))

    recall_ = recall_score(y_test, train_predictions)
    recall = recall_.round(3)
    print("Recall Score: {}".format(recall))
    
    print(f"\nClassic train score: {np.round(clf.score(X_train, y_train),4)}")
    print(f"Classic test score: {np.round(clf.score(X_test, y_test),4)}")
    confusion_matrix_ = confusion_matrix(y_test, train_predictions)
    print(f"Confusion matrix: \n{confusion_matrix_}\n")

#     train_predictions = clf.predict_proba(X_test)
    ll_ = log_loss(y_test, train_predictions)
    ll = ll_.round(3)
#     print("Log Loss: {}".format(ll))

    log_entry = pd.DataFrame([[name, acc*100, fbeta, roc, precision, recall, ll]], columns=log_cols)
    log = pd.concat([log,log_entry])

# print("="*30)
# type(coef_scores)
# print(index)
# print(log_entry)
# type(log)
# Out:
# ============================================================
# KNeighborsClassifier
# ****Results****
# Accuracy: 89.3000%
# F1 Score: 0.447
# AUC (ROC) Score: 0.665
# Precision Score: 0.569
# Recall Score: 0.368
#
# Classic train score: 0.9365
# Classic test score: 0.8926
# Confusion matrix:
# [[11519   446]
#  [ 1011   588]]
#
# ============================================================
# DecisionTreeClassifier
# ****Results****
# Accuracy: 87.0000%
# F1 Score: 0.456
# AUC (ROC) Score: 0.693
# Precision Score: 0.45
# Recall Score: 0.462
#
# Classic train score: 1.0
# Classic test score: 0.87
# Confusion matrix:
# [[11063   902]
#  [  861   738]]
#
# ============================================================
# RandomForestClassifier
# ****Results****
# Accuracy: 90.1000%
# F1 Score: 0.445
# AUC (ROC) Score: 0.656
# Precision Score: 0.655
# Recall Score: 0.336
#
# Classic train score: 1.0
# Classic test score: 0.9009
# Confusion matrix:
# [[11682   283]
#  [ 1061   538]]
#
# ============================================================
# AdaBoostClassifier
# ****Results****
# Accuracy: 89.6000%
# F1 Score: 0.453
# AUC (ROC) Score: 0.666
# Precision Score: 0.601
# Recall Score: 0.363
#
# Classic train score: 0.9017
# Classic test score: 0.8965
# Confusion matrix:
# [[11579   386]
#  [ 1018   581]]
#
# ============================================================
# GradientBoostingClassifier
# ****Results****
# Accuracy: 90.3000%
# F1 Score: 0.488
# AUC (ROC) Score: 0.681
# Precision Score: 0.65
# Recall Score: 0.391
#
# Classic train score: 0.9123
# Classic test score: 0.9033
# Confusion matrix:
# [[11628   337]
#  [  974   625]]
#
# ============================================================
# GaussianNB
# ****Results****
# Accuracy: 82.6000%
# F1 Score: 0.414
# AUC (ROC) Score: 0.694
# Precision Score: 0.343
# Recall Score: 0.522
#
# Classic train score: 0.8326
# Classic test score: 0.8258
# Confusion matrix:
# [[10366  1599]
#  [  764   835]]
#
# ============================================================
# BernoulliNB
# ****Results****
# Accuracy: 88.1000%
# F1 Score: 0.434
# AUC (ROC) Score: 0.666
# Precision Score: 0.496
# Recall Score: 0.385
#
# Classic train score: 0.886
# Classic test score: 0.8814
# Confusion matrix:
# [[11339   626]
#  [  983   616]]
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ============================================================
# MLPClassifier
# ****Results****
# Accuracy: 89.4000%
# F1 Score: 0.53
# AUC (ROC) Score: 0.726
# Precision Score: 0.556
# Recall Score: 0.507
#
# Classic train score: 0.9776
# Classic test score: 0.8942
# Confusion matrix:
# [[11319   646]
#  [  789   810]]
#
# ============================================================
# MLPClassifier
# ****Results****
# Accuracy: 88.9000%
# F1 Score: 0.516
# AUC (ROC) Score: 0.722
# Precision Score: 0.529
# Recall Score: 0.504
#
# Classic train score: 0.9979
# Classic test score: 0.8886
# Confusion matrix:
# [[11247   718]
#  [  793   806]]
#
# ============================================================
# LinearDiscriminantAnalysis
# ****Results****
# Accuracy: 90.2000%
# F1 Score: 0.516
# AUC (ROC) Score: 0.704
# Precision Score: 0.616
# Recall Score: 0.444
#
# Classic train score: 0.9011
# Classic test score: 0.9018
# Confusion matrix:
# [[11522   443]
#  [  889   710]]
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\reagins\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# ============================================================
# LogisticRegression
# ****Results****
# Accuracy: 90.1000%
# F1 Score: 0.447
# AUC (ROC) Score: 0.658
# Precision Score: 0.648
# Recall Score: 0.341
#
# Classic train score: 0.9038
# Classic test score: 0.9005
# Confusion matrix:
# [[11669   296]
#  [ 1053   546]]
#
# ============================================================
# QuadraticDiscriminantAnalysis
# ****Results****
# Accuracy: 84.3000%
# F1 Score: 0.411
# AUC (ROC) Score: 0.679
# Precision Score: 0.369
# Recall Score: 0.463
#
# Classic train score: 0.8485
# Classic test score: 0.8433
# Confusion matrix:
# [[10697  1268]
#  [  858   741]]

# %%
# Save DF as PNG
def render_mpl_table(imputed_df, col_width=6.0, row_height=0.625, font_size=10,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(imputed_df.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')
    mpl_table = ax.table(cellText=imputed_df.values, bbox=bbox, colLabels=imputed_df.columns, **kwargs)
    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in mpl_table._cells.items():
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax.get_figure(), ax

fig,ax = render_mpl_table(log, header_columns=0, col_width=3.0)
fig.savefig("table_mpl.png")

# %%
log1 = log.set_index('Classifier')

norm_df = log1 / log1.max(0)

sns.heatmap(norm_df.astype('float'),cmap='coolwarm')
# Out:
# <AxesSubplot:ylabel='Classifier'>

# %%
#plt.figure(figsize=(24,3))
#sns.barplot(X.columns,logreg.coef_[0])
#plt.xticks(rotation=60)
#plt.title("Extracting the Feature Importance");

# %% [markdown]
# ### Further discussion for the group
# * **What further refinements to the dataset should we make as part of the EDA / cleanup?**
#     * Removing the *pdays* variable, for example
#     * Dropping outliers
# * **How might the use of other classification algorithms and scalers affect the final predictions?**
#     * ~Algorithms like LogisticRegression, DecisionTree, RandomForest, Kneighbors, NaiveBayes, neural net, etc.~
#     * Scalers like StandardScaler, MinMaxScaler, RobustScaler
#     * PCA (principal component analysis) to reduce dimensions
# * **Playing with parameters, pipelines, gridsearches to maximize True Negatives and minimize False Negatives**
#     * That is, maximize deposit==1 correct predictions and reducing deposit==0 wrong predictions
#     * Even if that means accidentally overpredicting the number of true deposits, better to try a bad path than miss a potential business opportunity
# * **Extending this to other predictions**
#     * e.g. predicting the "default" variable, or some other classification
#     * e.g. predicting a range for continuous values based on categorical values
# * **Best ways to impute missing data?**
#     *
